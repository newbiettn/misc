# %% [markdown]
# # Fine-tuning + context-learning for a CodeLlama-2 Python model for Ops Data transform generations

# %% [markdown]
# ## Installing and loading the libraries

# %%
# !pip install "transformers" "datasets" "peft" "accelerate" "bitsandbytes" "trl" "safetensors>=0.3.1" "accelerate" --upgrade
# Out:
# Collecting transformers
#   Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 23.7 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 38.2 MB/s eta 0:00:00
# Collecting peft
#   Downloading peft-0.6.2-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.7/174.7 kB 26.8 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 33.8 MB/s eta 0:00:00
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.41.2.post2-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 19.8 MB/s eta 0:00:00
# Collecting trl
#   Downloading trl-0.7.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 21.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 41.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 106.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.5-py3-none-any.whl (7.8 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.1.0+cu118)
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.5.14-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.1.0)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.6.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.6.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Installing collected packages: bitsandbytes, shtab, safetensors, pyarrow-hotfix, docstring-parser, dill, multiprocess, huggingface-hub, tyro, tokenizers, accelerate, transformers, datasets, trl, peft
# Successfully installed accelerate-0.24.1 bitsandbytes-0.41.2.post2 datasets-2.15.0 dill-0.3.7 docstring-parser-0.15 huggingface-hub-0.19.4 multiprocess-0.70.15 peft-0.6.2 pyarrow-hotfix-0.5 safetensors-0.4.0 shtab-1.6.4 tokenizers-0.15.0 transformers-4.35.2 trl-0.7.4 tyro-0.5.14

# %%
# !pip install ipywidgets==7.7.1
# !pip install huggingface_hub
# !pip install python-dotenv
# !pip install sentencepiece
# Out:
# Requirement already satisfied: ipywidgets==7.7.1 in /usr/local/lib/python3.10/dist-packages (7.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (3.0.9)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1) (6.3.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets==7.7.1)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (4.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.1) (0.8.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (3.1.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (5.5.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.18.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets==7.7.1) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.7.1) (0.2.9)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (4.19.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client->ipykernel>=4.5.1->ipywidgets==7.7.1) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.12.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.6.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.21)
# Installing collected packages: jedi
# Successfully installed jedi-0.19.1
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.0 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from datasets import load_dataset
from random import randrange

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, TrainingArguments, CodeLlamaTokenizer, pipeline
from peft import LoraConfig, prepare_model_for_kbit_training, get_peft_model, AutoPeftModelForCausalLM

from trl import SFTTrainer
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(

# %% [markdown]
# ## Setting Global Parameters

# %%
# The model that you want to train from the Hugging Face hub
model_id = "codellama/CodeLlama-7b-Python-hf"
# The instruction dataset to use
dataset_name = "newbiettn/ops_transforms"
# Dataset split
dataset_split= "train"
# Fine-tuned model name
new_model = "CodeLlama-7b-Python-hf-fine-tuned"
# Huggingface repository
hf_model_repo="newbiettn/"+new_model
# Load the entire model on the GPU 0
device_map = {"": 0}

################################################################################
# bitsandbytes parameters
################################################################################
# Activate 4-bit precision base model loading
use_4bit = True
# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"
# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"
# Activate nested quantization for 4-bit base models (double quantization)
use_double_nested_quant = False

################################################################################
# QLoRA parameters
################################################################################
# LoRA attention dimension
lora_r = 64
# Alpha parameter for LoRA scaling
lora_alpha = 16
# Dropout probability for LoRA layers
lora_dropout = 0.1

################################################################################
# TrainingArguments parameters
################################################################################
# Output directory where the model predictions and checkpoints will be stored
output_dir = new_model
# Number of training epochs
num_train_epochs = 200
# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = True
# Batch size per GPU for training
per_device_train_batch_size = 64
# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1 # 2
# Enable gradient checkpointing
gradient_checkpointing = True
# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3
# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4 #1e-5
# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001
# Optimizer to use
optim = "paged_adamw_32bit"
# Learning rate schedule
lr_scheduler_type = "cosine" #"constant"
# Number of training steps (overrides num_train_epochs)
max_steps = -1
# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03
# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = False
# Save checkpoint every X updates steps
save_steps = 0
# Log every X updates steps
logging_steps = 100
# Disable tqdm
disable_tqdm= True

################################################################################
# SFTTrainer parameters
################################################################################
# Maximum sequence length to use
max_seq_length = 2048 #None
# Pack multiple short examples in the same input sequence to increase efficiency
packing = True #False

# %% [markdown]
# ## Connect to Huggingface Hub

# %% [markdown]
# Log in to Hugging Face Hub using token

# %%
from huggingface_hub import login

# Login to the Hugging Face Hub
login(token="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")
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## Load the dataset with the instruction set

# %%
# Load dataset from the hub
dataset = load_dataset(dataset_name, split=dataset_split)
# Show dataset size
print(f"dataset size: {len(dataset)}")
# Show an example
print(dataset[randrange(len(dataset))])
# Out:
# Downloading readme:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# dataset size: 57
# {'instruction': 'In Lexer OpsData Pyspark transform codes, Create get_validated_year_of_birth() function. This function takes a year column that is the length of 4 and accepts year later than 1900 until the current year. Cast the result as integer. It will return Null for invalid year', 'input': 'yob', 'output': 'def get_validated_year_of_birth(yob:Column) -> Column:\n  """This function is used to validate and format year of birth column.\n  """\n  yob = F.when(yob.rlike("\\d{4}"), yob).otherwise(F.lit(None))\n  yob = F.when((yob >= 1900) & (yob <= F.year(F.current_date())), yob).otherwise(F.lit(None))\n  yob = yob.cast("int")\n  return yob'}

# %%
# Check the dataset structure
dataset
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 57
# })

# %%
# Show a random example
print(dataset[randrange(len(dataset))])
# Out:
# {'instruction': 'In Lexer OpsData Pyspark transform codes, Persist customer_source using filter_most_recent() function based on input column', 'input': 'customer_id', 'output': 'customer_persist = filter_most_recent(source= customer_source, \n                                  filter_cols= "customer_id",\n                                  date_pattern=r"\\/imports\\/(\\d{4}\\/\\d{2}\\/\\d{2})")'}

# %% [markdown]
# To fine-tune our model, we need to convert our structured examples into a collection of tasks described via instructions. We define a formatting_function that takes a sample and returns a string with our instruction format.

# %%
def format_instruction(sample):
	return f"""### Instruction:
Use the Task below and the Input given to write the Response, which is a programming code that can solve the following Task:

### Task:
{sample['instruction']}

### Input:
{sample['input']}

### Response:
{sample['output']}
"""

# %%
# Set the instruction format for HuggingFaceH4/CodeAlpaca_20K
#def format_instruction(sample):
	#return f"""### Instruction:
#You are a coding assistant that will write a Solution to resolve the following Task:"

### Task:
#{sample['prompt']}

### Solution:
#{sample['completion']}
#"""

# %%
# Show a formatted instruction
print(format_instruction(dataset[randrange(len(dataset))]))
# Out:
# ### Instruction:
# Use the Task below and the Input given to write the Response, which is a programming code that can solve the following Task:
#
# ### Task:
# In Lexer OpsData Pyspark transform codes, Cast input column as string. This replace the current input column
#
# ### Input:
# age
#
# ### Response:
# customer_persist = customer_persist.withColumn("age", F.col("age").cast("string"))

# %% [markdown]
# ## Instruction fine-tune a Llama 2 model using trl and the SFTTrainer

# %% [markdown]
# We will use the recently introduced method in the paper "QLoRA: Quantization-aware Low-Rank Adapter Tuning for Language Generation" by Tim Dettmers et al. QLoRA is a new technique to reduce the memory footprint of large language models during finetuning, without sacrificing performance.
#
# Quantize the pre-trained model to 4 bits and freeze it.
# Attach small, trainable adapter layers. (LoRA)
# Finetune only the adapter layers while using the frozen quantized model for context.

# %%
# Get the type
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

# BitsAndBytesConfig int-4 config
bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_use_double_quant=use_double_nested_quant,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype
)

# %%
# Load the pretrained model
model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, use_cache = False, device_map=device_map)
model.config.pretraining_tp = 1

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# (…)ma-7b-Python-hf/resolve/main/config.json:   0%|          | 0.00/644 [00:00<?, ?B/s]
# (…)esolve/main/model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# (…)n-hf/resolve/main/generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# (…)on-hf/resolve/main/tokenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# (…)7b-Python-hf/resolve/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# (…)-hf/resolve/main/special_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]

# %% [markdown]
# The SFTTrainer supports a native integration with peft, which makes it super easy to efficiently instruction tune LLMs. We only need to create our LoRAConfig and provide it to the trainer.

# %%
# LoRA config based on QLoRA paper
peft_config = LoraConfig(
        lora_alpha=lora_alpha,
        lora_dropout=lora_dropout,
        r=lora_r,
        bias="none",
        task_type="CAUSAL_LM",
)
# Not necessary when using SFTTrainer
# prepare model for training
# model = prepare_model_for_kbit_training(model)
# model = get_peft_model(model, peft_config)

# %%
# !rm -rf sample_data

# %% [markdown]
# Before we can start our training we need to define the hyperparameters (TrainingArguments) we want to use

# %%
# Define the training arguments
args = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size, # 6 if use_flash_attention else 4,
    gradient_accumulation_steps=gradient_accumulation_steps,
    gradient_checkpointing=gradient_checkpointing,
    optim=optim,
    #save_steps=save_steps,
    logging_steps=logging_steps,
    save_strategy="epoch",
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    warmup_ratio=warmup_ratio,
    #max_steps=max_steps,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    disable_tqdm=disable_tqdm,
    report_to="tensorboard",
    seed=42
)

# %% [markdown]
# We now have every building block we need to create our SFTTrainer to start then training our model.

# %%
# Create the trainer
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    packing=packing,
    formatting_func=format_instruction,
    args=args,
)

# %% [markdown]
# Start training our model by calling the train() method on our Trainer instance.

# %%
# train
trainer.train() # there will not be a progress bar since tqdm is disabled

# save model in local
trainer.save_model()
# Out:
# You're using a CodeLlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.3705, 'learning_rate': 0.00010485622221144484, 'epoch': 100.0}
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.0069, 'learning_rate': 0.0, 'epoch': 200.0}
# {'train_runtime': 1165.6244, 'train_samples_per_second': 9.78, 'train_steps_per_second': 0.172, 'train_loss': 0.18873168915510177, 'epoch': 200.0}

# %% [markdown]
# ## Merge the model and the adapters and save it

# %% [markdown]
# When running in a T4 instance we have to clean the memory

# %%
# Empty VRAM
del model
del trainer
import gc
gc.collect()
# Out:
# 0

# %%
torch.cuda.empty_cache() # PyTorch thing

# %%
# !rm -rf merged_model

# %%
#gc.collect()

# %% [markdown]
# Reload the trained and saved model and merge it then we can save the whole model

# %%
from peft import AutoPeftModelForCausalLM

new_model = AutoPeftModelForCausalLM.from_pretrained(
    args.output_dir,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map=device_map,
)

# Merge LoRA and base model
merged_model = new_model.merge_and_unload()

# Save the merged model
merged_model.save_pretrained("merged_model", safe_serialization=True)
tokenizer.save_pretrained("merged_model")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ('merged_model/tokenizer_config.json',
#  'merged_model/special_tokens_map.json',
#  'merged_model/tokenizer.model',
#  'merged_model/added_tokens.json',
#  'merged_model/tokenizer.json')

# %%
# push merged model to the hub
merged_model.push_to_hub(hf_model_repo)
tokenizer.push_to_hub(hf_model_repo)
# Out:
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/newbiettn/CodeLlama-7b-Python-hf-fine-tuned/commit/6bb5490b0cfc470eb96b4c5fa74aab8e554898c9', commit_message='Upload tokenizer', commit_description='', oid='6bb5490b0cfc470eb96b4c5fa74aab8e554898c9', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ## Test the merged model

# %% [markdown]
# It is time to check our model performance

# %%
sample = dataset[randrange(len(dataset))]

prompt = f"""### Instruction:
Use the Task below and the Input given to write the Response, which is a programming code that can solve the following Task:

### Task:
{sample['instruction']}

### Input:
{sample['input']}

### Response:
"""

input_ids = tokenizer(prompt, return_tensors="pt", truncation=True).input_ids.cuda()
# with torch.inference_mode():
outputs = merged_model.generate(input_ids=input_ids, max_new_tokens=100, do_sample=True, top_p=0.9,temperature=0.5)

print(f"Prompt:\n{prompt}\n")
print(f"\nGenerated instruction:\n{tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0][len(prompt):]}")
print(f"\nGround truth:\n{sample['output']}")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Prompt:
# ### Instruction:
# Use the Task below and the Input given to write the Response, which is a programming code that can solve the following Task:
#
# ### Task:
# In Lexer OpsData Pyspark transform codes, Create map_gender() function to change M to Male and F to Female. This function takes gender column and map its value
#
# ### Input:
# gender
#
# ### Response:
#
#
#
# Generated instruction:
# # Define udf
# map_gender =udf(lambda x: "Male" if x=="M" else "Female" if x=="F" else x, StringType())
#
#
# Ground truth:
# def map_gender(gender):
#     return when(gender == 'M', 'Male').when(gender == 'F', 'Female').otherwise(gender)

# %%
# Run an new inference
prompt = f"""### Instruction:
Use the Input below to create an instruction, which could have been used to generate the input using an LLM.

### Input:
{sample['output']}

### Response:
"""

print(f"Prompt:\n{sample['output']}\n")
print(f"Generated instruction:\n{tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0][len(prompt):]}")
print(f"Ground truth:\n{sample['instruction']}")
# Out:
# Prompt:
# def map_gender(gender):
#     return when(gender == 'M', 'Male').when(gender == 'F', 'Female').otherwise(gender)
#
# Generated instruction:
# s function takes gender column and map its value
#
# ### Input:
# gender
#
# ### Response:
# # Define udf
# map_gender =udf(lambda x: "Male" if x=="M" else "Female" if x=="F" else x, StringType())
#
# Ground truth:
# In Lexer OpsData Pyspark transform codes, Create map_gender() function to change M to Male and F to Female. This function takes gender column and map its value

# %% [markdown]
# ## Load the model from the HF Hub and test it
#
# ---

# %% [markdown]
# Finally we download the created model from the hub and test it to make sure it works fine!

# %%
# If not defined
hf_model_repo='newbiettn/CodeLlama-7b-Python-hf-fine-tuned'

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Get the tokenizer
tokenizer = AutoTokenizer.from_pretrained(hf_model_repo)
# Load the model
model = AutoModelForCausalLM.from_pretrained(hf_model_repo, load_in_4bit=True, torch_dtype=torch.float16,
                                             device_map=device_map)
# Create an instruction
instruction="Load all SFTP JSON file that has a file pattern from the S3 bucket"
input="*_user.json"

prompt = f"""### Instruction:
Use the Task below and the Input given to write the Response, which is a programming code that can solve the Task.

### Task:
{instruction}

### Input:
{input}

### Response:
"""
# Tokenize the input
input_ids = tokenizer(prompt, return_tensors="pt", truncation=True).input_ids.cuda()
# Run the model to infere an output
outputs = model.generate(input_ids=input_ids, max_new_tokens=100, do_sample=True, top_p=0.9,temperature=0.5)

# Print the result
print(f"Prompt:\n{prompt}\n")
print(f"Generated instruction:\n{tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0][len(prompt):]}")
# Out:
# (…)tuned/resolve/main/tokenizer_config.json:   0%|          | 0.00/1.78k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# (…)f-fine-tuned/resolve/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# (…)ine-tuned/resolve/main/added_tokens.json:   0%|          | 0.00/87.0 [00:00<?, ?B/s]
# (…)ned/resolve/main/special_tokens_map.json:   0%|          | 0.00/535 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# (…)n-hf-fine-tuned/resolve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# (…)esolve/main/model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:992: UserWarning: Not enough free disk space to download the file. The expected file size is: 4938.99 MB. The target location /root/.cache/huggingface/hub only has 1292.01 MB free disk space.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:992: UserWarning: Not enough free disk space to download the file. The expected file size is: 4938.99 MB. The target location /root/.cache/huggingface/hub/models--newbiettn--CodeLlama-7b-Python-hf-fine-tuned/blobs only has 1292.01 MB free disk space.
#   warnings.warn(
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-28-5e806ca1676d> in <cell line: 7>()
#       5 tokenizer = AutoTokenizer.from_pretrained(hf_model_repo)
#       6 # Load the model
# ----> 7 model = AutoModelForCausalLM.from_pretrained(hf_model_repo, load_in_4bit=True, torch_dtype=torch.float16,
#       8                                              device_map=device_map)
#       9 # Create an instruction
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     564         elif type(config) in cls._model_mapping.keys():
#     565             model_class = _get_model_class(config, cls._model_mapping)
# --> 566             return model_class.from_pretrained(
#     567                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     568             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3126         if is_sharded:
#    3127             # rsolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 3128             resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    3129                 pretrained_model_name_or_path,
#    3130                 resolved_archive_file,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1050         try:
#    1051             # Load from URL
# -> 1052             cached_filename = cached_file(
#    1053                 pretrained_model_name_or_path,
#    1054                 shard_filename,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     428     try:
#     429         # Load from URL or cache if already cached
# --> 430         resolved_file = hf_hub_download(
#     431             path_or_repo_id,
#     432             filename,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     116             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#     120     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1459                     _check_disk_space(expected_size, local_dir)
#    1460
# -> 1461             http_get(
#    1462                 url_to_download,
#    1463                 temp_file,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in http_get(url, temp_file, proxies, resume_size, headers, expected_size, _nb_retries)
#     542                 if chunk:  # filter out keep-alive new chunks
#     543                     progress.update(len(chunk))
# --> 544                     temp_file.write(chunk)
#     545                     new_resume_size += len(chunk)
#     546                     # Some data has been downloaded from the server so we reset the number of retries.
#
# /usr/lib/python3.10/tempfile.py in func_wrapper(*args, **kwargs)
#     620             @_functools.wraps(func)
#     621             def func_wrapper(*args, **kwargs):
# --> 622                 return func(*args, **kwargs)
#     623             # Avoid closing the file as long as the wrapper is alive,
#     624             # see issue #18879.
#
# OSError: [Errno 28] No space left on device

# %% [markdown]
# ## Context-learning on Ops-Data codes
#
# ---

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install "langchain" "faiss-cpu" "huggingface-hub" "sentence-transformers"
# Out:
# Collecting langchain
#   Downloading langchain-0.0.336-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 12.4 MB/s eta 0:00:00
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 59.6 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (0.19.4)
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 14.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.8.6)
# Requirement already satisfied: anyio<4.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.7.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.2-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<0.1.0,>=0.0.63 (from langchain)
#   Downloading langsmith-0.0.64-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.23.5)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub) (2023.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub) (23.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.35.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.16.0+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain) (1.1.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.6 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=aaca5fb9678c4b017545180cc94d4b15ad9e278e339c0d6744045b823b170975
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: faiss-cpu, mypy-extensions, marshmallow, jsonpointer, typing-inspect, langsmith, jsonpatch, dataclasses-json, langchain, sentence-transformers
# Successfully installed dataclasses-json-0.6.2 faiss-cpu-1.7.4 jsonpatch-1.33 jsonpointer-2.4 langchain-0.0.336 langsmith-0.0.64 marshmallow-3.20.1 mypy-extensions-1.0.0 sentence-transformers-2.2.2 typing-inspect-0.9.0

# %%
import os
from langchain.document_loaders import TextLoader
from langchain.chains import ConversationalRetrievalChain
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.llms import LlamaCpp, HuggingFacePipeline
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores.faiss import FAISS
from langchain.callbacks.base import BaseCallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
from google.colab import drive
drive.mount('ngoctran', force_remount=True)
# Out:
# Mounted at ngoctran

# %%
root_dir = '/content/ngoctran/MyDrive/hackoween/codes/'
docs= []
for dirpath,dirnames, filenames in os.walk(root_dir):
  for file in filenames:
    try:
      print(file)
      loader=TextLoader(os.path.join(dirpath,file),encoding='utf-8')
      docs.extend(loader.load_and_split())
    except Exception as e:
      pass

text_splitter = CharacterTextSplitter(chunk_size=1000,chunk_overlap=0)
texts=text_splitter.split_documents(docs)
# Out:
# activations_backload.py
# base_consumerviewau.py
# schedules.py
# forms_backload.py
# base_consumerviewusa.py
# generate_new_schedules.py
# migrate.py
# enrichment_functions.py
# forgotten_customers_bulk_notebook.py
# form_functions.py
# dataset_functions.py
# forgotten_customer_notebook.py
# compare_dataflows.py
# dataflow_functions.py
# compare_build_index_runs.py
# client_dataset_count.py
# get_bk_schedules.py
# check_schedules.py
# get_ops_schedules.py
# test_profiles.py
# purge.py
# process_activations.py
# supply_transform.py
# supply_enrichment.py
# enrichment.py
# alternating_least_squares.py
# locality_sensitive_hashing.py
# wide_view.py
# enrichment.py
# training.py
# ltv_xgboost_training_12x.py
# enrichment.py
# enrichment_keyfix.py
# deterministic_qa.py
# deterministic.py
# inference.py
# benchmark_calendar_years.py
# insights_delta_transform.py
# benchmark_aggregations_export.py
# benchmark_calendar_months.py
# benchmark_calendar_weeks.py
# general_validation.py
# truncate_dataset.py
# activations_backload.py
# load_datasets_staging.py
# forms_backload.py
# attribute_recall.py
# build_index.py
# dummy_job.py
# load_dataset.py
# run_dataflow.py
# multi_notebook.py
# run_enrichment.py
# attribute_events_delta.py
# subscriber_status_qa.py
# spend_decile_check.py
# shopify_sources.py
# plezzel_transform.py
# listrak_transform.py
# hubspot_v1.py
# simplified_schema_transform.py
# incremental_magento_V2.py
# sprout.py
# bigcommerce_V2.py
# dotdigital.py
# incremental_salesforce_marketing.py
# salesforce_marketing.py
# woocommerce_v2.py
# mailchimp.py
# cordial.py
# incremental_emarsys_V2.py
# cheetah_digital.py
# bigcommerce.py
# incremental_dotdigital_V2.py
# incremental_listrak_v1.py
# lightspeed.py
# marketo.py
# incremental_dotdigital_v3.py
# klaviyo.py
# shopify_bundles.py
# integration_streaming.py
# klaviyo-V2.py
# marketplacer.py
# incremental_emarsys_v1.py
# incremental_campaign_monitor_v2.py
# shopify.py
# incremental_lexer_serve.py
# bronto.py
# magento_v2.py
# incremental_klaviyo_v2.py
# mailchimp_v2.py
# vision6.py
# mryum_V2.py
# shopify_tax-fork.py
# incremental_attentive.py
# yotpo.py
# incremental_mryum_V2.py
# incremental_klaviyo_v3.py
# ontempo.py
# activecampaign_V1.py
# incremental_shopify_v2.py
# braze.py
# hubspot_list_status_enrichment.py
# shopify_order_id_list.py
# yotpo_reviews.py
# delta_forward.py
# experian_au.py
# segment_id.py
# attentive_subscription.py
# pre_unification.py
# inferred_country.py
# spend_decile.py
# scroll_query.py
# preferred_store.py
# preferred_store_reference.py
# birthday_from_forms.py
# incremental_klaviyo_list_status.py
# attribute_recall_enrichment.py
# plezzel_custom_attributes.py
# sprout_enrichment.py
# subscribed_emails.py
# premium_products.py
# salesforce_list_status.py
# source_records.py
# cordial_list_status.py
# spend_over_specified_date_ranges.py
# experian_usa.py
# country_code.py
# klaviyo_list_status.py
# load_multi_flat_files.py
# yotpo.py
# bounce_email_enrichment.py
# activecampaign_list_status.py
# marketplacer.py
# kathmandu_sfmc_enrichment.py
# kathmandu_loyalty.py
# kathmandu_sfmc.py
# kathmandu_sftp_enrichment.py
# kathmandu_sku_tags.py
# kathmandu_bazaarvoice_enrichment.py
# kathmandu_sfmc_persist.py
# kathmandu_sftp.py
# kathmandu_freshdesk_enrichment.py
# kathmandu_campaign_name_enrichment.py
# order_time_enrichment.py
# app_download_enrichment.py
# bettysburgers_transaction_transform.py
# dayofweek_and_storeid_enrichment.py
# sportswhereiam_sftp_imports.py
# transaction_enrichment.py
# meandu_transform.py
# zenglobal_enrichment.py
# meandu_enrichment.py
# ivvy_flatfile_transform.py
# sevenrooms_enrichment.py
# ivvy_enrichment.py
# zenglobal_transform.py
# sevenrooms_flatfile_transform.py
# reference_names.py
# update_datasets.py
# copy_subset.py
# update_shopify.py
# update_klaviyo.py
# reference_products.py
# blueillusion_transform_v2.py
# blueillusion_transform.py
# tgv_zohodesk_enrichment.py
# tgv_zohodesk_transform.py
# tgv_surveymonkey_transform.py
# tgv_dw_enrichment.py
# tgv_loyalty_transform.py
# tgv_loyalty_enrichment.py
# tgv_engine_mailer.py
# tgv_dw_transform.py
# tgv_surveymonkey_enrichment.py
# Lovisa_Futura_transform.py
# proflag.py
# interests_enrichment.py
# makeupcartel_historic_magento_v2_transform.py
# klaviyo_enrichment.py
# magento_exported_shopify.py
# boardriders_loyalty_status_enrichment.py
# boardriders_optin_enrichment.py
# boardriders_brand_transaction_enrichment.py
# boardriders_adobe_email_read.py
# boardriders_email_data_load.py
# boardriders_flatfile_data_read.py
# boardriders_customer_data_load.py
# martha_liftengine_export.py
# martha_drinks_oneoff_transform.py
# martha_drinkscustomer_flag.py
# marthastewart_sellable.py
# martha_oneoff_transform.py
# marthastewart_quarterly_spend_attributes_enrichment.py
# martha_liftengine_validation.py
# shopify_record.py
# ls_direct_export.py
# all_historic.py
# historic_retail.py
# historic_ecom.py
# bigquery_persist.py
# bigquery_ecom_transform.py
# boozebud_transform.py
# marketplace_transform.py
# static_sfmc_transform.py
# adhoc_campaigns_transform.py
# shopify_brand_spends.py
# shopify_product_transform.py
# brand_enrichment.py
# blockv_transform.py
# inferred_region.py
# cub_custom_activecampaign_attributes.py
# blockv_campaigns_enrichment.py
# brunomagli_sellable.py
# zendesk_transform.py
# zendesk_enrichment.py
# gorgias_transform.py
# spending_enrichment.py
# nps_transform.py
# gorgias_enrichment.py
# product_sftp.py
# plezzel_combine_etl.py
# seller_propensity_scores.py
# seller_propensity_model.py
# marshallwhite_file_check.py
# next_birthday.py
# vinomofo_flat_file_transform.py
# vinomofo_varietal_enrichment.py
# jpeterman_historic_flat_file.py
# netsuite_transform.py
# historic_email_subscribe_transform.py
# vault_enrichment.py
# horseland_magento_enrichment.py
# ls_nav_pos_transform.py
# skyfii_data_enrichment.py
# post_event_nps_surveys_daily_export.py
# skyfii_data_load.py
# jotform_data_enrichment.py
# form_enrichment.py
# jotform_data_load.py
# nps_surveys_daily_export.py
# centre_optins_enrichment.py
# campaign_monitor_enrichment.py
# qcrowd_signup_form_enrichment.py
# skyfii_data_transform.py
# quantium_crowd_enrichment.py
# zimmermann_transform.py
# omneo_attributes_enrichment.py
# zimmermann_customer_enrichment.py
# wholesaler_flag.py
# roadshow_marketo_enrichment.py
# ripcurl_salesforce_marketing_persist.py
# ripcurl_group_flat_file_transform.py
# ripcurl_salesforce_marketing_fit.py
# ripcurl_transaction_custom_enrichment.py
# ripcurl_flatfile_data_load.py
# generate_config.py
# cottonon_loyalty_sms_transform.py
# cottonon_loyalty_led_transform.py
# cottonon_transaction_store_item_delta.py
# cottonon_ltv_rollup.py
# cottonon_email_delta.py
# cottonon_loyalty_subs_transform.py
# cottonon_email_transform.py
# cottonon_transaction_store_transform.py
# cottonon_product_transform.py
# cottonon_customer_transform.py
# motherhoodpea_customattributes_enrichment.py
# motherhood_historic_flat_file_transform.py
# marquee_revcascade_enrichment.py
# bronto.py
# netsuite_old.py
# product_enrichment.py
# netsuite.py
# loyalty_enrichment.py
# theupside_flat_file_transform.py
# theupside_clv_enrichment.py
# theupside_upgrades_transform_qa.py
# bodyglove_sellable.py
# qic_skyfii_data_transform.py
# qic_skyfii_data_enrichment.py
# qcrowd_segment_enrichment.py
# vii_giftcard_enrichment.py
# birth_month_attribute_enrichment.py
# vii_giftcard_transform.py
# prospects_transform.py
# properties_transform.py
# properties_enrichment.py
# propertyme_customers_flatfile_transform.py
# customers_flatfile_transform.py
# customers_enrichment.py
# property_management_enrichment.py
# smrtr_enrichment.py
# marketing_customers_flatfile_transform.py
# apg_flat_file_transform.py
# pii_forms_enrichment.py
# apg_pii_transform.py
# apg_activation_linkage.py
# apg_custom_attributes.py
# historic_pii_import.py
# apg_rfm_custom_attributes.py
# ap21_card_id_linkage.py
# palmerhospitalitygroup_flat_file_transform.py
# zenglobal_flat_file_transform.py
# sevenrooms_flat_file_transform.py
# zenglobal_customer_enrichment.py
# order_enrichment.py
# decjuba_flat_file_transform_v2.py
# decjuba_flat_file_transform.py
# avene_pebble_post_import.py
# narvar_returns_enrichment.py
# incremental_klaviyo_v2_qa.py
# territoryahead_historic_flat_file.py
# aptos_daily_transform.py
# aptos_enrichment.py
# optus_enrichment.py
# transaction_enrichment.py
# skjewellery_sftp.py
# subscription-status-transform.py
# subscription_enrichment.py
# bensherman_sellable.py
# mevo_forms_export.py
# us_shopify_historics.py
# ssigroup_historic_flat_file_transform.py
# ssigroup_flat_file_transform.py
# ssi_customer_enrichment.py
# ssigroup_msl_enrichment.py
# trunc_msl_enrichment.py
# msl_enrichment.py
# ssigroup_group_flat_file_transform.py
# direct_mail.py
# product_categories.py
# sku_mapping.py
# mini_sample_breakout.py
# yotpo-transform-supergoop.py
# yotpo_flat_file_import.py
# bulk_orders.py
# custom_fields.py
# attentive.py
# historic_ecomm_transform.py
# aquila_arche_job.py
# aquila_streaming_test.py
# aquila_streaming_test_qa.py
# delta_ecomm_transform.py
# mancrates_flat_file_transform.py
# okendo-from-klaviyo.py
# netsuite_products.py
# mryum_transform.py
# avc_pivot_enrichment.py
# sevenrooms_transform.py
# update_venue_mapping.py
# ivvy_transform.py
# primary_email_mobile_enrichment.py
# loyalty_enrichment.py
# sprout_loyalty_enrichment.py
# avc_transaction_enrichment.py
# oztix_enrichment.py
# loke_transform.py
# sevenrooms_enrichment.py
# avc_venue_enrichment.py
# mgl_streaming_files.py
# mgl_enrichment.py
# mgl_transform.py
# sprout_transactions.py
# oztix_transform.py
# ivvy_enrichment.py
# ripcurl_flatfile_data_load.py
# ripcurl_group_flat_file_transform.py
# loyalty_from_tags.py
# product_enrichment_transform.py
# outlet_email_enrichment.py
# kwi_possible_duplicate_flag.py
# historic_transaction_transform.py
# store_enrichment.py
# listrak_transform.py
# kwi_feed.py
# csc_enrichment.py
# csc_transformation.py
# saint_flat_file_transform.py
# apeainthepod_historic_flat_file_transform.py
# mevo_teledemand_export.py
# optus_lxptsvc_delta.py
# mevo_owned_media_export.py
# optus_new_id_attributes_transform.py
# telmkt_extract.py
# c360_experian_export.py
# store_enrichment.py
# optus_churn_capi_transform.py
# file_import_checker.py
# optus_lxptsvc_transform.py
# bq_subhub_import.py
# nba_enrichment.py
# dmg_enrichment.py
# optus_capi_transform.py
# optus_forms.py
# delacon_enrichment.py
# optus_conversions.py
# ob_leads_sfmc_export.py
# illion_flatfile_transform.py
# bq_subhub_enrichment.py
# telmkt_enrichment.py
# once_off_enrichment.py
# ga_sessions_export.py
# bq_partyid_export.py
# mevo_experian_export.py
# optus_svc_transform.py
# optus_experian.py
# mevo_sales_export.py
# svc_enrichment.py
# bq_dailyfile_export.py
# optus_lxserv_transform.py
# optus_ssd_business.py
# udd_enrichment.py
# optus_ssd_transform.py
# dinovite_bigcommerce_v2_transform.py
# healthy_life_transform.py
# healthy_life_klaviyo_enrichment.py
# harrisscarfe_flat_file_transform.py
# emarsys_V1toV2_adapter_transform.py
# update_shopify.py
# reference_products.py
# reference_names.py
# copy_subset.py
# update_klaviyo.py
# update_datasets.py
# calendly_data_transform.py
# quiz_transform.py
# promo_code_enrichment.py
# megatix_custom_attributes.py
# megatix.py
# barpop-eventbrite-historic.py
# willow_export.py
# attribute_recall_enrichment.py
# vc_export.py
# marquee_order_dates_by_channel.py
# bbb_export.py
# marquee_customattributes_enrichment.py
# marquee_flat_file_transform.py
# hatley_export.py
# similac_export.py
# lovevery_export.py
# automate_stats_dm.py
# mjn_export.py
# marquee_sellableflag_enrichment.py
# child_customattributes_enrichment.py
# maternity_historic_flat_file_transform.py
# liftengine_export.py
# export_source.py
# liftengine_validation.py
# viacord_validation.py
# lovevery_validation.py
# meadjohnson_validation.py
# similac_validation.py
# validator.py
# buybuybaby_validation.py
# MJN-Export-Validator.py
# Willow-Export-Validator.py
# Maternity-LiftEngine-Export-Validator-v1.py
# Similac-Export-Validator.py
# Viacord-Export-Validator.py
# Lovevery-Export-Validator.py
# bbB-Export-Validator.py
# fiveeleven_beyond_emails_transform.py
# blend_360_append_dob_enrich.py
# last_ordered_pants.py
# closest_store.py
# fiveeleven_firstparty_transform.py
# fiveeleven_sweepstakes_transform.py
# fiveeleven_firstparty_historic_transform.py
# emarsys_V1toV2_adapter_transform.py
# idme_bopis_promo_enrich.py
# blueridge_enrichment.py
# blueridge_customer_flatfile.py
# justgroup_bigquery_transaction_transform_v2.py
# justgroup_last_two_days_v2.py
# justgroup_customer_attributes_enrichment_v2.py
# justgroup_bigquery_email_transform.py
# justgroup_grouphub_customer_attributes_enrichment.py
# multibrand_attributes.py
# justgroup_bigquery_transaction_transform.py
# justgroup_bigquery_email_transform_v2.py
# custom_email_attributes.py
# justgroup_bigquery_data_ingestion_incremental.py
# justgroup_last_two_days.py
# justgroup_customer_attributes_enrichment.py
# justgroup_grouphub_first_party_data.py
# BCBG-LiftEngine-Export-Validator-v1.py
# bcbg_liftengine_validation.py
# liftengine_export.py
# bcbg_sellable.py
# export_source.py
# polywood_customer_experience_transform.py
# marketing_categories_enrichment.py
# product_enrichment_transform.py
# preferences_enrichment.py
# bespoke_churn_enrichment.py
# navision_transform.py
# customer_contact_enrichment.py
# customer_enrichment.py
# wine_societies_enrichment.py
# prospect_enrichment.py
# transaction_enrichment.py
# experimental_churn_prediction_tensorflow.py
# transaction_enrichment.py
# nps_transform.py
# transaction_custom_fields_enrichment.py
# earlysettler_sftp.py
# attribute_recall_enrichment.py
# jpo_group_flat_file.py
# cthreesixtyoptus_flat_file_transform.py
# marquee_and_motherly_email_link.py
# lift_engine_send_to_export_enrichment.py
# marqueebrands_sellable.py
# export_source.py
# surlatable_csc_sweepstakes.py
# surlatable_sellable_enrichment.py
# surlatable_store_catchment_enrichment.py
# surlatable_historic_flat_file_transform.py
# liftengine_export.py
# surlatable_flat_file_transform.py
# surlatable_customer_attributes_enrichment.py
# surlatable_right_at_home_enrichment.py
# SLT-LiftEngine-Export-Validator.py
# surlatable_liftengine_validation.py
# theiconic_flat_file_transform.py
# transaction_enrichment.py
# age_enrichment.py
# rbgayalaland_flat_file_transform.py
# history_enrichment.py
# wondercide_klaviyo_custom_attributes_transform.py
# wondercide_refresh_email_list_transform.py
# wondercide_sweepstakes_transform.py
# wondercide_klaviyo_enrichment.py
# product_category_family.py
# smart_waiver_transform.py
# cin7.py
# hamper_attribute_enrichment.py
# hamper_emporium_transform.py
# nps_transform.py
# sftp_returns_transform.py
# proapp_roster.py
# first_party_data_v2.py
# dealer_records.py
# SBG_list_upload.py
# profession_enrichment.py
# navision_historic_transform.py
# pro_data.py
# pro_list_update.py
# retail_data_transform.py
# ticketmaster_transform.py
# subscription_enrichment.py
# uppercase_email_sha_enrichment.py
# moshtix_transform.py
# ticketek_enrichment.py
# ticketek_transform.py
# subscription_transform.py
# subscription_persist_transform.py
# camping_enrichment.py
# date_of_birth.py
# historic_ecom.py
# merged_customer_supplemental_edges.py
# gifts_attribute_enrichment.py
# gifts_aus_transform.py
# forms_export.py
# main_enrichment.py
# movio_transform_to_persist.py
# email_unification_links.py
# movio_transform_to_fit.py
# rfm_enrichment.py
# giftcard_transform.py
# ticket_transform.py
# villagecinemas_flat_file_transform.py
# food_&_beverage_transform.py
# loyalty_enrichment.py
# nps_enrichment.py
# WARNING:langchain.text_splitter:Created a chunk of size 3313, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1883, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1073, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1747, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1108, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3212, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2262, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1302, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1470, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1315, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1644, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2609, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1316, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2609, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2049, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1030, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1426, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1772, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1076, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1050, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1599, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1554, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1120, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1551, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1053, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3061, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1217, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1217, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2859, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1656, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1281, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1020, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1288, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3313, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3183, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1003, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1048, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1617, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1426, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1372, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1201, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1146, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1048, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1409, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2235, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3613, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2336, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1069, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1347, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1196, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1698, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2121, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1786, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1043, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1783, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1082, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1350, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1859, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1714, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2332, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1782, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2788, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1614, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1187, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1362, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1817, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2712, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1190, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1735, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3725, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1690, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2659, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3783, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2473, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2347, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2027, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2924, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2361, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1805, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2774, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3898, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2588, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2462, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2142, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3039, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2476, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2169, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1531, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1170, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3561, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1752, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1286, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1390, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1097, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1503, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3871, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2004, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2260, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1136, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1770, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1919, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1448, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1444, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1605, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1535, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1089, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1200, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1156, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1153, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1675, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3813, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1111, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1374, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1100, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1368, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2453, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1146, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2437, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1823, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1183, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1627, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1117, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2220, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1044, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1175, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1021, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1214, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1261, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1651, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2037, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1055, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1036, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1772, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1125, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2648, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2416, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1565, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2341, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1899, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1351, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2117, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1618, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2217, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1130, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1297, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1004, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1658, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1488, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1708, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1038, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1370, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1731, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1875, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2035, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1055, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1527, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1527, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1363, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1013, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1946, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2010, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1055, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1036, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1772, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1125, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1205, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3647, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1991, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1138, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1638, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1394, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2610, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3575, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1861, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1601, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1103, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1457, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2250, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2332, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1782, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1170, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2341, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1941, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1351, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2276, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1116, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1523, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2068, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1094, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1587, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1329, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1065, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1118, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3047, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1161, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1275, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1027, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1481, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1632, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1056, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1036, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1771, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1010, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1205, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3767, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1991, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1139, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1647, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1403, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2370, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1708, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2416, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1583, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3047, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1161, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1275, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1027, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1481, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1437, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1165, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1256, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2235, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2400, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1250, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1391, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1093, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1839, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1058, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1209, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1037, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1469, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2266, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1179, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1205, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1159, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2448, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1772, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2659, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1035, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1165, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1189, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3178, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1005, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2204, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1841, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1123, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2774, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1173, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3561, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1785, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1180, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2765, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2183, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1904, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2201, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2297, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2102, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1058, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1057, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1245, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1410, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3403, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1095, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1097, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2100, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3372, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1183, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1082, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1903, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1339, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1614, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1505, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2949, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1008, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2038, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1396, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1544, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1175, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2113, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1110, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1530, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1839, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1107, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3437, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1896, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1662, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1380, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1110, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2321, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1761, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1895, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1110, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2538, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1007, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2239, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1341, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1087, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1718, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1021, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1342, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1190, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1360, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1360, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1472, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2433, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1125, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1183, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1424, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1424, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1536, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2406, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1125, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1183, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1324, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2673, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1663, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1011, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1101, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2002, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1574, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2468, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1145, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1332, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1004, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2089, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1295, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2044, which is longer than the specified 1000
# ...
# WARNING:langchain.text_splitter:Created a chunk of size 3239, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1060, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1127, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1405, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1036, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3219, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1111, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1183, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1736, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1127, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1405, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1057, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1132, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1427, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1225, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1093, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1651, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1139, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1630, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1449, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1075, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1567, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1220, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1070, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1363, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1247, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1313, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1049, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1376, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1084, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1201, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3179, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1205, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1157, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2007, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3667, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2337, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1564, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1158, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1155, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1041, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1075, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2260, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1800, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2451, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1686, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1161, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2397, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2714, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1110, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1152, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1442, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1024, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2218, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1895, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1457, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1439, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1445, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1500, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2198, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1125, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1205, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2207, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1019, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1794, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1067, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1772, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2652, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1125, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1205, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1249, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2077, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2077, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1549, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1132, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1676, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1225, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1094, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1081, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2770, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2060, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2391, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1419, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2113, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1125, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1205, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1230, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1449, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2225, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1047, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1143, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1607, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1048, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2820, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2894, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1071, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3380, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1032, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1840, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1212, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1169, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1852, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3018, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1196, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1095, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1370, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1260, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1476, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1808, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1053, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1571, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1370, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1325, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1680, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1098, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1565, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3301, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1992, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1447, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1074, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1331, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2197, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1697, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3878, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1326, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1133, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1972, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1074, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1151, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1008, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1074, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1074, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1450, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1045, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1720, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1885, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1169, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2119, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2192, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1187, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1569, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1010, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1562, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2975, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2374, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3085, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1759, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1338, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1554, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2534, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2377, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3085, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2332, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1308, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1871, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1546, which is longer than the specified 1000

# %%
embeddings= HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
faiss_index = FAISS.from_documents(texts,embeddings)
faiss_index.save_local("/content/ngoctran/MyDrive/hackoween/index")
# Out:
# (…)f3d3c277d6e90027e55de9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# (…)7d6e90027e55de9125/1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# (…)e2f80f3d3c277d6e90027e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# (…)f80f3d3c277d6e90027e55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# (…)de9125/config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# (…)d3c277d6e90027e55de9125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# (…)90027e55de9125/sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# (…)6e90027e55de9125/special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# (…)f3d3c277d6e90027e55de9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# (…)7d6e90027e55de9125/tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# (…)3d3c277d6e90027e55de9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# (…)e2f80f3d3c277d6e90027e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# (…)80f3d3c277d6e90027e55de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
print("loading indexes")
faiss_index=FAISS.load_local("/content/ngoctran/MyDrive/hackoween/index",embeddings)
retriever = faiss_index.as_retriever()
retriever.search_kwargs['distance_metric']='cos'
retriever.search_kwargs['fetch_k']=100
retriever.search_kwargs['maximal_marginal_relevance']=True
print("index loaded")
# Out:
# loading indexes
# index loaded

# %%
model = AutoModelForCausalLM.from_pretrained(hf_model_repo, load_in_4bit=True, torch_dtype=torch.float16,
                                             device_map=device_map)
# Out:
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# (…)uned/resolve/main/generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %%
def format_instruction(sample):
	return f"""### Instruction:
  Use the Task below and the Input given to write the Response, which is a programming code that can solve the following Task:

  ### Task:
  {sample['instruction']}

  ### Input:
  {sample['input']}

  """

question = {
      "instruction": "You are a Pyspark expert. Write a Pyspark script to read all SFTP files *_hackoween.json from the S3 bucket",
      "input": "*_hackoween.json"
}
format_instruction(question)
# Out:
# '### Instruction:\n  Use the Task below and the Input given to write the Response, which is a programming code that can solve the following Task:\n\n  ### Task:\n  You are a Pyspark expert. Write a Pyspark script to read all SFTP files *_hackoween.json from the S3 bucket\n\n  ### Input:\n  *_hackoween.json\n\n  '

# %%
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=2048,
    temperature=0,
    top_p=0.95,
    repetition_penalty=1.15,
    batch_size=1,
)
llm = HuggingFacePipeline(pipeline=pipe)

# %%
qa = ConversationalRetrievalChain.from_llm(llm,retriever=retriever)
chat_history = []
question = {
      "instruction": "You are a Pyspark expert. Load all SFTP JSON file that has a file pattern from the S3 bucket. SFTP files means files that are always in /imports and the file pattern is always /imports/{year}/{month}/{date}/ ",
      "input": "*_user_data.json"
}
while(True):
    print("Enter a question: ")
    result = qa({"question":format_instruction(question),"chat_history":chat_history})
    chat_history.append((format_instruction(question),result['answer']))
    print(result['answer'])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:386: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Enter a question:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:386: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# def load_sftp_files(config: HubSpotJobConfig) -> None:
#     df_list: List[DataFrame] = []
#     if Config.load_style == "HISTORIC":
#       df_list = [
#           sc.read.format("csv").options(
#               escape="\"", quote="\"").load(
#                   f"s3://{Config.bucket}/imports/*/*/*/*_customer_data.csv",
#                   header=True,
#                   sep=",",
#           ),
#           sc.read.format("csv").options(
#               escape="\"", quote="\"").load(
#                   f"s3://{Config.bucket}/imports/*/*/*/*_order_data.csv",
#                   header=True,
#                   sep=",",
#           ),
#           sc.read.format("csv").options(
#               escape="\"", quote="\"").load(
#                   f"s3://{Config.bucket}/imports/*/*/*/*_transaction_data.csv",
#                   header=True,
#                   sep=",",
#           ),
#       ]
#     else:
#       df_list = [
#           sc.read.format("csv").options(
#               escape="\"", quote="\"").load(
#                   [
#                       f"{path}*_customer_data.csv"
#                       for path in Config.latest_avail_dirs(Config.file_days_ago)
#                       if S3Utils.path_exists(f"{path}*_customer_data.csv")
#                   ],
#                   header=True,
#                   sep=",",
#           ),
#           sc.read.format("csv").options(
#               escape="\"", quote="\"").load(
#                   [
#                       f"{path}*_order_data.csv"
#                       for path in Config.latest_avavil_dirs(Config.file_days_ago)
#                       if S3Utils.path_exists(f"{path}*_order_data.csv")
#                   ],
#                   header=True,
#                   sep=",",
#           ),
#           sc.read.format("csv").options(
#               escape="\"", quote="\"").load(
#                   [
#                       f"{path}*_transaction_data.csv"
#                       for path in Config.latest_avavil_dirs(Config.file_days_ago)
#                       if S3Utils.path_exists(f"{path}*_transaction_data.csv")
#                   ],
#                   header=True,
#                   sep=",",
#           ),
#       ]
#     rfm_source = Union(df_list).as_of(F.to_date('1970/01/01'))
#     rfm_source = add_input_file_date(rfm_source, "\d{4}/\d{2}/\d{2}")
#     # Use
# Enter a question:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-6e6ad4cee5f8> in <cell line: 7>()
#       7 while(True):
#       8     print("Enter a question: ")
# ----> 9     result = qa({"question":format_instruction(question),"chat_history":chat_history})
#      10     chat_history.append((format_instruction(question),result['answer']))
#      11     print(result['answer'])
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     308         except BaseException as e:
#     309             run_manager.on_chain_error(e)
# --> 310             raise e
#     311         run_manager.on_chain_end(outputs)
#     312         final_outputs: Dict[str, Any] = self.prep_outputs(
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     302         try:
#     303             outputs = (
# --> 304                 self._call(inputs, run_manager=run_manager)
#     305                 if new_arg_supported
#     306                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/conversational_retrieval/base.py in _call(self, inputs, run_manager)
#     137         if chat_history_str:
#     138             callbacks = _run_manager.get_child()
# --> 139             new_question = self.question_generator.run(
#     140                 question=question, chat_history=chat_history_str, callbacks=callbacks
#     141             )
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     508
#     509         if kwargs and not args:
# --> 510             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     511                 _output_key
#     512             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     308         except BaseException as e:
#     309             run_manager.on_chain_error(e)
# --> 310             raise e
#     311         run_manager.on_chain_end(outputs)
#     312         final_outputs: Dict[str, Any] = self.prep_outputs(
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     302         try:
#     303             outputs = (
# --> 304                 self._call(inputs, run_manager=run_manager)
#     305                 if new_arg_supported
#     306                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     106         run_manager: Optional[CallbackManagerForChainRun] = None,
#     107     ) -> Dict[str, str]:
# --> 108         response = self.generate([inputs], run_manager=run_manager)
#     109         return self.create_outputs(response)[0]
#     110
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     118         callbacks = run_manager.get_child() if run_manager else None
#     119         if isinstance(self.llm, BaseLanguageModel):
# --> 120             return self.llm.generate_prompt(
#     121                 prompts,
#     122                 stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     505     ) -> LLMResult:
#     506         prompt_strings = [p.to_string() for p in prompts]
# --> 507         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     508
#     509     async def agenerate_prompt(
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, **kwargs)
#     654                 )
#     655             ]
# --> 656             output = self._generate_helper(
#     657                 prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     658             )
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     542             for run_manager in run_managers:
#     543                 run_manager.on_llm_error(e)
# --> 544             raise e
#     545         flattened_outputs = output.flatten()
#     546         for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     529         try:
#     530             output = (
# --> 531                 self._generate(
#     532                     prompts,
#     533                     stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/huggingface_pipeline.py in _generate(self, prompts, stop, run_manager, **kwargs)
#     200
#     201             # Process batch of prompts
# --> 202             responses = self.pipeline(batch_prompts)
#     203
#     204             # Process each response in the batch
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     206               ids of the generated text.
#     207         """
# --> 208         return super().__call__(text_inputs, **kwargs)
#     209
#     210     def preprocess(
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1119                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1120                 )
# -> 1121                 outputs = list(final_iterator)
#    1122                 return outputs
#    1123             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     122
#     123         # We're out of items within a batch
# --> 124         item = next(self.iterator)
#     125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     123         # We're out of items within a batch
#     124         item = next(self.iterator)
# --> 125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#     127         if self.loader_batch_size is not None:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1044                 with inference_context():
#    1045                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1046                     model_outputs = self._forward(model_inputs, **forward_params)
#    1047                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1048             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     269
#     270         # BS x SL
# --> 271         generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     272         out_b = generated_sequence.shape[0]
#     273         if self.framework == "pt":
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1671         if generation_mode == GenerationMode.GREEDY_SEARCH:
#    1672             # 11. run greedy search
# -> 1673             return self.greedy_search(
#    1674                 input_ids,
#    1675                 logits_processor=logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in greedy_search(self, input_ids, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2519
#    2520             # forward pass to get next token
# -> 2521             outputs = self(
#    2522                 **model_inputs,
#    2523                 return_dict=True,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     162                 output = module._old_forward(*args, **kwargs)
#     163         else:
# --> 164             output = module._old_forward(*args, **kwargs)
#     165         return module._hf_hook.post_forward(module, output)
#     166
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1032
#    1033         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1034         outputs = self.model(
#    1035             input_ids=input_ids,
#    1036             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     162                 output = module._old_forward(*args, **kwargs)
#     163         else:
# --> 164             output = module._old_forward(*args, **kwargs)
#     165         return module._hf_hook.post_forward(module, output)
#     166
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     920                 )
#     921             else:
# --> 922                 layer_outputs = decoder_layer(
#     923                     hidden_states,
#     924                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     162                 output = module._old_forward(*args, **kwargs)
#     163         else:
# --> 164             output = module._old_forward(*args, **kwargs)
#     165         return module._hf_hook.post_forward(module, output)
#     166
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     684         residual = hidden_states
#     685         hidden_states = self.post_attention_layernorm(hidden_states)
# --> 686         hidden_states = self.mlp(hidden_states)
#     687         hidden_states = residual + hidden_states
#     688
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     162                 output = module._old_forward(*args, **kwargs)
#     163         else:
# --> 164             output = module._old_forward(*args, **kwargs)
#     165         return module._hf_hook.post_forward(module, output)
#     166
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, x)
#     256             down_proj = sum(down_proj)
#     257         else:
# --> 258             down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#     259
#     260         return down_proj
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     162                 output = module._old_forward(*args, **kwargs)
#     163         else:
# --> 164             output = module._old_forward(*args, **kwargs)
#     165         return module._hf_hook.post_forward(module, output)
#     166
#
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py in forward(self, x)
#     251         inp_dtype = x.dtype
#     252         if self.compute_dtype is not None:
# --> 253             x = x.to(self.compute_dtype)
#     254
#     255         bias = None if self.bias is None else self.bias.to(self.compute_dtype)
#
# KeyboardInterrupt:
